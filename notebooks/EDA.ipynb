# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
median_income_by_state = pd.read_csv("../data/median_income_by_state.csv")

# %%
alabama_income = median_income_by_state.query("state == 'Alabama'")

alabama_income.plot(x = 'year')
plt.ylim(0,80000)
# Out:
# (0.0, 80000.0)
